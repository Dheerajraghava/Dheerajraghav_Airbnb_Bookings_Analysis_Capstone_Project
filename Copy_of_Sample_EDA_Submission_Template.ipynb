# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheerajraghava/Dheerajraghav_Airbnb_Bookings_Analysis_Capstone_Project/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AirBnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Member -**        - Dheeraj Raghav

# %% [markdown]
# # **Project Summary -**
#
# I selected this project as its seems intresting to me. And Airbnb business model look just like we have in  india named as oyo rooms but with little difference.
# As i looked into the AirBnb data sheet we see multiples columns and rows.
# some of the columns are ,ID,price,neighabourhood groups,neighabourhood,minimum nights etc.
#
#
# Airbnb is an American San Francisco-based company operating an online marketplace for short- and long-term homestays and experiences. The company acts as a broker and charges a commission from each booking. The company was founded in 2008 by Brian Chesky, Nathan Blecharczyk, and Joe Gebbia. Airbnb is a shortened version of its original name, AirBedandBreakfast.com.
#
# Airbnb is an online marketplace that connects people who want to rent out their homes with people who are looking for accommodations in that locale. It currently covers more than 100,000 cities and 220 countries worldwide. For hosts, it's a way to earn money while protecting their property from potential damage.
#
# For this project we are analyzing Airbnb’s New York City(NYC) data. NYC is not only the most famous city in the world but also top global destination for visitors drawn to its museums, entertainment, restaurants and commerce. According to the Office of New York State Comptroller, NYC hosted 66.6 million visitors in 2019.
#
# Our main objective is to find out the key metrics that influence the listing of properties on the platform. For this, we will explore and visualize the dataset from Airbnb in NYC using basic exploratory data analysis (EDA) techniques. We have found out the distribution of every Airbnb listing based on their location, including their price range, room type, listing name, and other related factors. We have analyzed this dataset from different angles and have come up with interesting insights. This can help in making strategic data-driven decisions by the marketing team, finance team and technical team of Airbnb.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Dheerajraghava/Dheerajraghav_Airbnb_Bookings_Analysis_Capstone_Project/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Q1. Total number of rows and columns?
# q2. Number of Null values in each coloums and find way to remove or replace them?
# Q3. How many Missing values are there in data set?
# Q4. Are there any duplicate rows values and coloums?
# Q5. What are the columns name?
# Q6. Which neighbarhood group have higest price.and which have lowest?
# Q7. Highest Avrage prices of all Neigbourhood group?
# Q8. Host with maximum number of AirBnb listing?
# Q9.Type of room with maximum listeing?
# Q10. Which neighbourhood group have maximum number of Airbnb?
# Q11. Aavailability of Airbnb in each neighbourhood?
# Q12. what is the correlatation between prices and availability?
# Q13. Percentage of AirBnb in diffrent neighbourhood group.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To conduct the analysis as described, we'll first need to explore and analyze the data related to Airbnb listings to gain insights into different hosts, areas, and predictions. The steps we'll follow are as follows:
#
# Understand the Problem:
#
# 1. We'll review the dataset and understand the variables it contains, such as 'Price,' 'Location,' 'Reviews,' 'Hosts,' etc.
# We'll analyze the relevance and significance of each variable for the problem at hand, which is likely related to pricing, location popularity, and host behavior.
#
# 2. We'll explore how the 'Price' variable is related to other independent variables like 'Location,' 'Reviews,' 'Hosts,' etc.
# This analysis can involve scatter plots, correlation matrices, and other visualization techniques to identify potential patterns or relationships.
# Basic Cleaning:
#
# 3. We'll handle missing data and convert categorical variables into numerical format (if required).
# Cleaning the dataset is crucial to ensure the accuracy of our analysis.
# Test Assumptions:
#
# 4. Based on the analysis, we'll draw key understandings about different hosts and areas.
# We'll identify factors that contribute to higher demand for certain listings, and how price, location, and reviews influence each other.
#
# 5. Busiest Hosts and Reasons:We'll identify the busiest hosts based on factors like the number of bookings, occupancy rates, etc.
#
# 6. To facilitate the analysis, we may perform data visualization, statistical tests, and machine learning techniques if applicable. We will also document our findings and present them in a clear and meaningful manner.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing all usefull Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
#Mpunting the google drive for load the data sheet.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/EMD Project Airbnb NYC 2019 by Dheeraj Raghav/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#  In this data sheet there are 48896 rows and 16 columns.

# %% [markdown]
# ###  Data sheet have 48896 rows and 16 columns.

# %% [markdown]
# ### Dataset Information

# %%
# # Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# #CLEANING OF DATA SHEET ✈

# %% [markdown]
# ## Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().value_counts()

#no duplicate value count
# Out:
# False    48895
# dtype: int64

# %%
# Checking subset duplicate
data.duplicated(subset=['id']).value_counts()

#no subset duplicate
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# We need to drop all duplicate rows if its there as it can creat problem in machine learning algorithm and other data science task.⚠️
# As no duplicate rows are present in data sheet we dont have to drop any duplicate rows.

# %% [markdown]
# ## Missing Values/Null Values😶

# %%
#Null Values Count
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# We analysis that there are -:
#
# Column  - null count
#
# 1.   name -16
# 2.   host_name - 21
# 3.   last_reviews -10052
# 4.   reviews_per_month - 10052

# %% [markdown]
# ## We initially remove last_review since it appears to contain a large number of null values that cannot be replaced.Additionally, this column appears to be of very little significance when analyzing the data sheet.💧

# %%
data1=data.drop(columns=['last_review'],axis=1)
data1.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %% [markdown]
# ##Substituting '0' for NaN values for reviews_per_month.Due of the apparent importance of this column in the analysis of the data sheet.

# %%
data1.fillna({'reviews_per_month':0},inplace=True)

# %% [markdown]
# ## We may eliminate any rows with 0 availability_365 since it is impossible to have an Airbnb with 0 availability.

# %%
#we can drop all rows with 0 availability_365 or we can sent mail to the client for information.

data1.drop(data1[data1['availability_365']==0].index,inplace=True)

# %%
data1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.136200e+04  3.136200e+04  31362.000000  31362.000000  31362.000000
# mean   2.100481e+07  8.144950e+07     40.728401    -73.948745    162.050475
# std    1.148631e+07  8.673088e+07      0.056561      0.051397    254.425463
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420      0.000000
# 25%    1.167514e+07  8.620116e+06     40.688383    -73.983270     70.000000
# 50%    2.254548e+07  4.109561e+07     40.723720    -73.954110    111.500000
# 75%    3.119407e+07  1.452145e+08     40.763030    -73.930132    189.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    31362.000000       31362.000000       31362.000000
# mean         8.338658          31.852369           1.509593
# std         23.836703          51.636804           1.781266
# ...

# %% [markdown]
# ## We may eliminate any rows with 0 price since it is impossible to have an Airbnb with 0 charge.

# %%
data1.drop(data1[data1['price']==0].index,inplace=True)
data1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.135400e+04  3.135400e+04  31354.000000  31354.000000  31354.000000
# mean   2.100493e+07  8.145071e+07     40.728406    -73.948753    162.091822
# std    1.148777e+07  8.673941e+07      0.056562      0.051400    254.444750
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420     10.000000
# 25%    1.167354e+07  8.619004e+06     40.688392    -73.983280     70.000000
# 50%    2.255750e+07  4.108975e+07     40.723725    -73.954115    112.000000
# 75%    3.119452e+07  1.452368e+08     40.763037    -73.930152    189.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    31354.000000       31354.000000       31354.000000
# mean         8.338426          31.849365           1.509464
# std         23.838961          51.638559           1.781202
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31354 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              31354 non-null  int64
#  1   name                            31350 non-null  object
#  2   host_id                         31354 non-null  int64
#  3   host_name                       31346 non-null  object
#  4   neighbourhood_group             31354 non-null  object
#  5   neighbourhood                   31354 non-null  object
#  6   latitude                        31354 non-null  float64
#  7   longitude                       31354 non-null  float64
#  8   room_type                       31354 non-null  object
#  9   price                           31354 non-null  int64
#  10  minimum_nights                  31354 non-null  int64
#  11  number_of_reviews               31354 non-null  int64
# ...

# %% [markdown]
# #              CLEAN DATA SET
#
# ![download.jpg](data:image/jpeg;base64,...)

# %%
data1.reset_index().head()
# Out:
#    index    id                                       name  host_id  \
# 0      0  2539         Clean & quiet apt home by the park     2787
# 1      1  2595                      Skylit Midtown Castle     2845
# 2      2  3647        THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3  3831            Cozy Entire Floor of Brownstone     4869
# 4      5  5099  Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Dataset gives us the complete overview of bussiness model of Airbnb an online market an online marketplace that connects people who want to rent out their property with people who are looking for accommodations in specific locales. Its an Amarican company.
#
# This data sheet porived us the complete information of host who have listed there properties on Airbnb.
# It provied us the host name with there ID's ,there property location ,logititude and latitude,property neighbourhood,property information like type of room,its Prices,minimum nights,rooms availability in 365 days,property number of reviews per month.
#
# By studing dataset
# 1. We found out that there are 48895 rows and 16 coloums total.
# 2. There are 16 null values in property ['name']coloum,21 null values in ['host_name'] column,10052 null values in  ['last_review'] column,10052 null value in ['reviews_per_month'].
# 3. There is no missing values in data set.
# 4. There is no duplicate rows values and coloums
# 5. We have 'Id' of all the listed AirBnb
# 6. We have 'name' column with all names of property.
# 7. We have 'host_name' colomn with all the host names.
# 8. We have all the neighbourhood_group where all AirBnb are situated.
# 8. We have 'neighbourhood' local area of AirBnb.
# 9. We have exact 'latitude-longitude' of all AirBnb.
# 10. We have 'room types' listed.
# 11. We have 'prices' of all Airbib per night.
# 12. We have 'minimum nights' of each AirBnb.
# 13. We have 'availability_365'.
#
# After cleaning of data sheet we came up with 31354 rows and 13 columns.
#
# 1. Due to the abundance of NuN values in the name, host_name, and last_review columns, we have removed them from the table.drop(columns=[''],axis=1).
#
# 2. We replaced all NuN values in the'reviews_per_month' field with 0.using the data1.fillna method.
#
# 3. All of the property rows with 0 availability_365 have been removed, and we have drop any rows with prices  0.
#
# ![download.png](data:image/png;base64,...)
#
# After cleaning of data sheet we came up with 31354 rows and 13 columns.
#
# 1. We have droped the 'name,'host_name',and 'last_review' columns as they have many NuN values  with the help of data.drop(columns=[''],axis=1).
#
# 2. We have replace all NuN values in of 'reviews_per_month' with 0.with data1.fillna{} function.
#
# 3. We have drop all the rows of properties with 0 availability_365 and extract all rows whose price is greater than 0.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
data1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.135400e+04  3.135400e+04  31354.000000  31354.000000  31354.000000
# mean   2.100493e+07  8.145071e+07     40.728406    -73.948753    162.091822
# std    1.148777e+07  8.673941e+07      0.056562      0.051400    254.444750
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420     10.000000
# 25%    1.167354e+07  8.619004e+06     40.688392    -73.983280     70.000000
# 50%    2.255750e+07  4.108975e+07     40.723725    -73.954115    112.000000
# 75%    3.119452e+07  1.452368e+08     40.763037    -73.930152    189.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    31354.000000       31354.000000       31354.000000
# mean         8.338426          31.849365           1.509464
# std         23.838961          51.638559           1.781202
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# 1. id'= Range from 2539-36487245 (Continuous variable).
# 2. Host_id'= Range from 2787-68119814 (Continuous variable).
# 3. Neighbourhood_group= example-Manhattan,Brokley categorical variable.
# 4. Neighbourhood= categorical variable.
# 5. Longitude = Continuous variable.
# 6. Room_type = (Private room,Entire home/apt..etc)Categorical variable.
# 7. Price= Continuous Variable.with minimun `10$ and maximum 10000 $ `Inline code`with avrage of 162 $
# 8. Minimum_nights= continuous numaric data.With minimum nights 1 - 1250 with avrage of 8 nights
# 9. Number_of_reviews= Continous variable.
# 10. Reviews_per_month= Contiouns variable.
# 11. Calculated_host_listings_count-contiouns numarical data.
# 12. Availability_365- contionus variable.minumim 1 to maximum 365 days.

# %% [markdown]
# ## For each variable, look for Unique Values.

# %%
# Check Unique Values for each variable.
unique_values=data1['id'].nunique()
print(f'id Unique values = {unique_values}')

unique_values=data1['host_id'].nunique()
print(f'host_id Unique values = {unique_values}')

unique_values=data1['neighbourhood_group'].nunique()
print(f'neighbourhood_group Unique values = {unique_values}')

unique_values=data1['room_type'].nunique()
print(f'room type Unique values = {unique_values}')

unique_values=data1['calculated_host_listings_count'].nunique()
print(f'calculated_host_listings_count Unique values = {unique_values}')

unique_values=data1['availability_365'].nunique()
print(f'availability_365 Unique values = {unique_values}')

unique_values=data1['price'].nunique()
print(f'price Unique values = {unique_values}')
# Out:
# id Unique values = 31354
# host_id Unique values = 21808
# neighbourhood_group Unique values = 5
# room type Unique values = 3
# calculated_host_listings_count Unique values = 47
# availability_365 Unique values = 365
# price Unique values = 644

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ## Most expansive AirBnb property at the top

# %%
most_expansive_properties=data1.sort_values('price',ascending= False)[['id','name','host_name','price','minimum_nights','neighbourhood_group','neighbourhood']].reset_index()
most_expansive_properties.head(5)
# Out:
#    index        id                                               name  \
# 0  29238  22436899                                1-BR Lincoln Center
# 1  12342   9528920                Quiet, Clean, Lit @ LES & Chinatown
# 2  40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...
# 3  30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho
# 4   4377   2953058                                      Film Location
#
#   host_name  price  minimum_nights neighbourhood_group    neighbourhood
# 0    Jelena  10000              30           Manhattan  Upper West Side
# 1       Amy   9999              99           Manhattan  Lower East Side
# 2      Matt   9999              30           Manhattan  Lower East Side
# 3       Rum   8500              30           Manhattan          Tribeca
# 4   Jessica   8000               1            Brooklyn     Clinton Hill

# %% [markdown]
# ## Top Most Affordable Properties

# %%
most_chepest_properties=data1.sort_values('price',ascending= True)[['id','name','host_name','price','minimum_nights','neighbourhood_group','neighbourhood']].reset_index()
most_chepest_properties.head(5)
# Out:
#    index        id                                               name  \
# 0  22835  18490141                            IT'S SIMPLY CONVENIENT!
# 1  31407  24412104                           Cozy feel at home studio
# 2  32810  25839759  Gigantic Sunny Room in Park Slope-Private Back...
# 3  33225  26235873                             Voted #1 Airbnb In NYC
# 4  35386  28071998                 Cozy room in a three-bedroom House
#
#   host_name  price  minimum_nights neighbourhood_group neighbourhood
# 0     Maria     10               1              Queens       Jamaica
# 1   Maureen     10               5           Manhattan      Kips Bay
# 2    Rachel     10               1            Brooklyn   Sunset Park
# 3     Maria     10               2              Queens       Jamaica
# 4    Arthur     10               7              Queens     Woodhaven

# %% [markdown]
# ## All AirBnb accommodations having private room type.

# %%
private_room_properties=data1[data1['room_type']=='Private room'].reset_index()
private_room_properties
# Out:
#        index        id                                               name  \
# 0          0      2539                 Clean & quiet apt home by the park
# 1          2      3647                THE VILLAGE OF HARLEM....NEW YORK !
# 2          7      5178                   Large Furnished Room Near B'way
# 3         11      5441                    Central Manhattan/near Broadway
# 4         12      5803     Lovely Room 1, Garden, Best Area, Legal rental
# ...      ...       ...                                                ...
# 13955  48888  36484087  Spacious Room w/ Private Rooftop, Central loca...
# 13956  48889  36484363                                 QUIT PRIVATE HOUSE
# 13957  48890  36484665    Charming one bedroom - newly renovated rowhouse
# 13958  48891  36485057      Affordable room in Bushwick/East Williamsburg
# 13959  48894  36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#          host_id   host_name neighbourhood_group       neighbourhood  \
# ...

# %% [markdown]
# ## All AirBnb accommodations have Entire home/apt'.

# %%
#Properties with 'Entire home/apt'.
properties_with_entire_home=data1[data1['room_type']=='Entire home/apt'].reset_index()
properties_with_entire_home
# Out:
#        index        id                                               name  \
# 0          1      2595                              Skylit Midtown Castle
# 1          3      3831                    Cozy Entire Floor of Brownstone
# 2          5      5099          Large Cozy 1 BR Apartment In Midtown East
# 3          9      5238                 Cute & Cozy Lower East Side 1 bdrm
# 4         10      5295                   Beautiful 1br on Upper West Side
# ...      ...       ...                                                ...
# 16527  48879  36480292  Gorgeous 1.5 Bdr with a private yard- Williams...
# 16528  48880  36481315  The Raccoon Artist Studio in Williamsburg New ...
# 16529  48886  36483010                    Comfy 1 Bedroom in Midtown East
# 16530  48887  36483152    Garden Jewel Apartment in Williamsburg New York
# 16531  48892  36485431            Sunny Studio at Historical Neighborhood
#
#          host_id      host_name neighbourhood_group    neighbourhood  \
# ...

# %% [markdown]
# ## All AirBnb accommodations have Shared room.

# %%
#Properties with 'Shared room'
property_with_sharedroom= data1[data1['room_type']=='Shared room'].value_counts().reset_index()
property_with_sharedroom
# Out:
#            id                                               name    host_id  \
# 0       12048                LowerEastSide apt share shortterm 1       7549
# 1    31168781    Amazing cozy and warm male room on Manhattan IV  170263842
# 2    31176143                         Beautiful shared apartment  129124146
# 3    31189073           Quite and comfortable shared room in UES   45317760
# 4    31208021     Next to subway station: Bunkbed accommodations  201015598
# ..        ...                                                ...        ...
# 856  23310309        MY HOUSE ON NEW YORK!! CLOSE TO JFK AND LGA  173290675
# 857  23329332  Bright, Shared Living Room in our Beautiful Home!  173754495
# 858  23329993   SHARE;Cheapest,Silent,Clean and Safe in New York  172837223
# 859  23343836   SHARE;CHEAPEST;Pure;Cozy;Safe;Silent IN NEW YORK  172837223
# 860  36485609               43rd St. Time Square-cozy single bed   30985759
#
# ...

# %%
#averange price of all properties listed.

avg_price=data1['price'].mean().round()
print(f'Avrage price of property listed = {avg_price}')
# Out:
# Avrage price of property listed = 162.0

# %% [markdown]
# What all manipulations have you done and insights you found?
#
# 1. We have extracted  top most expansive AirBnb property.
#
# Insights: Manhattan (1-BR Lincoln Center, Quiet), (Clean, Lit @ LES & Chinatown), and Brooklyn (Film Location) are home to the top 5 most expansive AirBnB listings. having a price range above 8000 dollars.
#
# 2. We have extracted top  most affordable Airbnb.
#
# Insights found- We found out that top most affordable AirBnb are in Queens (IT'S SIMPLY CONVENIENT!	) then (Cozy feel at home studio) in Manhattan and at last (Gigantic Sunny Room in Park Slope-Private Back..) in Brooklyn.
#
# 3. The proportion of all AirBnB accommodations that provide private rooms..
#
# Insights found- There are 13960 AirBnBs with individual rooms, according to insights.
#
# 4.  Number of All AirBnb accommodations having Entire home/apt'room type.
#
# Insights found- There are 16532 AirBnb having private room type.
#
# 5.  The total number of AirBnB properties that provide shared rooms.
#
# Insights found- There are 861 AirBnBs that offer private rooms.
#
# 6. The accommodation type "Entire home/apt" has the highest number of listing on AirBnB, according to insights.
#
# 7. Calculating Avrage of all AirBnb price.
#
# Insights-162 Rs. is the Avrage prices of AirBnb.
#
# 8. Total maximum reviews are 998605.
#
# 9. Highest numbers of reviews is at (Room near JFK Queen Bed) in Queens county near Jamaica with Id- 9145202.
#
# 10. AirBnb with top 5 lowest numbers of reviews are in Manhattan.It may be beacuse they are new praporties.

# %%
#Max number of reviews
data1['number_of_reviews'].sum()
# Out:
# 998605

# %%
#Airbnb with highest numbers of reviews.

data1.sort_values('number_of_reviews',ascending=False).head(1)[['id','name','host_id','neighbourhood_group',	'neighbourhood','number_of_reviews','reviews_per_month']]
# Out:
#             id                     name   host_id neighbourhood_group  \
# 11759  9145202  Room near JFK Queen Bed  47621202              Queens
#
#       neighbourhood  number_of_reviews  reviews_per_month
# 11759       Jamaica                629              14.58

# %%
#AirBnb with highest numbers of reviews per month

data1.sort_values('reviews_per_month',ascending=False).head(1)[['id','name','host_name','host_id','neighbourhood_group',	'neighbourhood','number_of_reviews','reviews_per_month','price']]
# Out:
#              id                                               name host_name  \
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!   Row NYC
#
#          host_id neighbourhood_group     neighbourhood  number_of_reviews  \
# 42075  244361589           Manhattan  Theater District                156
#
#        reviews_per_month  price
# 42075               58.5    100

# %%
#AirBnb with lowest numbers of reviews

data1[data1['number_of_reviews']==1].sort_values('number_of_reviews',ascending=True).head(5)[['id','name','host_id','neighbourhood_group',	'neighbourhood','number_of_reviews','reviews_per_month']]
# Out:
#              id                               name    host_id  \
# 97        21644          Upper Manhattan, New York      82685
# 43324  33585504  New 2 Bed 1 Bath in the UES #6131  113805886
# 43325  33585541             Lower East Side Studio    3817581
# 43352  33607319                  Share in cozy 1BR  253246141
# 43355  33607411                  Cozy room in Soho   69720852
#
#       neighbourhood_group    neighbourhood  number_of_reviews  \
# 97              Manhattan           Harlem                  1
# 43324           Manhattan  Upper East Side                  1
# 43325           Manhattan  Lower East Side                  1
# 43352           Manhattan      East Harlem                  1
# 43355           Manhattan             SoHo                  1
#
#        reviews_per_month
# 97                  0.11
# 43324               1.00
# 43325               0.77
# 43352               1.00
# 43355               0.34

# %%
# Filter the dataset for properties with a price of 132 $ or more
data1_filter1 = data1[data1['price']>=132]
data1_filter1
# Filter the dataset for movies with a popularity of 39.0 or higher
data1_filter2 = data1[data1['number_of_reviews']>=39]
data1_filter2

data1_filter_final = pd.concat([data1_filter1, data1_filter2],axis=0)
data1_filter_final
final = data1_filter_final.sort_values('price', ascending=False)[['price','number_of_reviews','id','name']].reset_index()
final.head(5)
# Out:
#    index  price  number_of_reviews        id  \
# 0  29238  10000                  0  22436899
# 1  12342   9999                  6   9528920
# 2  40433   9999                  0  31340283
# 3  30268   8500                  2  23377410
# 4   4377   8000                  1   2953058
#
#                                                 name
# 0                                1-BR Lincoln Center
# 1                Quiet, Clean, Lit @ LES & Chinatown
# 2  2br - The Heart of NYC: Manhattans Lower East ...
# 3  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho
# 4                                      Film Location

# %%
#Most expansive AirBnb accommodation naighbourhood.
data1.groupby('neighbourhood_group')['price'].mean().reset_index().sort_values('price',ascending=False)
# Out:
#   neighbourhood_group       price
# 2           Manhattan  214.202080
# 1            Brooklyn  132.928262
# 4       Staten Island  114.229607
# 3              Queens  100.029781
# 0               Bronx   89.105148

# %%
#Maximum number of properties in which neighbourhood_group.
data1.groupby('neighbourhood_group',)['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#   neighbourhood_group   name
# 2           Manhattan  13557
# 1            Brooklyn  12252
# 3              Queens   4298
# 0               Bronx    912
# 4       Staten Island    331

# %%
#Host with hight number of properties listed.

data1['host_name'].value_counts().reset_index().head(5)
# Out:
#           index  host_name
# 0  Sonder (NYC)        327
# 1       Michael        242
# 2    Blueground        232
# 3         David        228
# 4          John        211

# %%
#Which room type are maximum listed
data1['room_type'].value_counts().reset_index()
# Out:
#              index  room_type
# 0  Entire home/apt      16532
# 1     Private room      13960
# 2      Shared room        862

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *Answer* Here.
# What all manipulations have you done and insights you found?
#
# 1. We have extracted  top most expansive AirBnb property.
#
# Insights: Manhattan (1-BR Lincoln Center, Quiet), (Clean, Lit @ LES & Chinatown), and Brooklyn (Film Location) are home to the top 5 most expansive AirBnB listings. having a price range above 8000 dollars.
#
# 2. We have extracted top  most affordable Airbnb.
#
# Insights found- We found out that top most affordable AirBnb are in Queens (IT'S SIMPLY CONVENIENT!	) then (Cozy feel at home studio) in Manhattan and at last (Gigantic Sunny Room in Park Slope-Private Back..) in Brooklyn.
#
# 3. The proportion of all AirBnB accommodations that provide private rooms..
#
# Insights found- There are 13960 AirBnBs with individual rooms, according to insights.
#
# 4.  Number of All AirBnb accommodations having Entire home/apt'room type.
#
# Insights found- There are 16532 AirBnb having private room type.
#
# 5.  The total number of AirBnB properties that provide shared rooms.
#
# Insights found- There are 861 AirBnBs that offer private rooms.
#
# 6. The accommodation type "Entire home/apt" has the highest number of listing on AirBnB, according to insights.
#
# 7. Calculating Avrage of all AirBnb price.
#
# Insights-162 Rs. is the Avrage prices of AirBnb.
#
# 8. Total maximum reviews are 998605.
#
# 9. Highest numbers of reviews is at (Room near JFK Queen Bed) in Queens county near Jamaica with Id- 9145202.
#
# 10. AirBnb with top 5 lowest numbers of reviews are in Manhattan.It may be beacuse they are new praporties.
#
# 11. We found out the top host with maximum listing of AirBnb's.
#
# Insights- Sonder(NYC) and Michhale have maximum AirBnb's.
#
# 12. We have found which room type have maximum numbers of count AirBnb.
#
# Insights- Entire home/apt have maximum number of AirBnb's.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31354 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              31354 non-null  int64
#  1   name                            31350 non-null  object
#  2   host_id                         31354 non-null  int64
#  3   host_name                       31346 non-null  object
#  4   neighbourhood_group             31354 non-null  object
#  5   neighbourhood                   31354 non-null  object
#  6   latitude                        31354 non-null  float64
#  7   longitude                       31354 non-null  float64
#  8   room_type                       31354 non-null  object
#  9   price                           31354 non-null  int64
#  10  minimum_nights                  31354 non-null  int64
#  11  number_of_reviews               31354 non-null  int64
# ...

# %% [markdown]
# ## Chart - 1 visualization code
# ## Analyzing the average listing pricing on Airbnb in comparison to the neighborhood (location)

# %%
neighbourhood_grp_avg_price=data1.groupby('neighbourhood_group')['price'].mean().reset_index().sort_values('price',ascending=False)
neighbourhood_grp_avg_price.rename(columns={'price':'Avg.price'},inplace=True)
neighbourhood_grp_avg_price
# Out:
#   neighbourhood_group   Avg.price
# 2           Manhattan  214.202080
# 1            Brooklyn  132.928262
# 4       Staten Island  114.229607
# 3              Queens  100.029781
# 0               Bronx   89.105148

# %%
#Bar chart for Average prices of Airbnb listed properties in each Neighbourhood group.
av=sns.barplot(data=neighbourhood_grp_avg_price,x='neighbourhood_group',y='Avg.price')
av.set_ylabel('Average price')
av.set_xlabel('Neighbourhood_group')
av.set_title('Average pricing on Airbnb in comparison to the neighborhood',size=11)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have 'Neighbourhood_group' as a categorical variable, hence a bar chart was chosen. and a continuous variable for pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Due to its prominence as a center of global trade and tourism, Manhattan in New York City has the most high average price of Airbnb.
# 2. Brooklyn, commonly known as Kings County, is the most populous county in New York City and has the most sprawling AirBnBs after Manhattan hence have 2nd highest average price of AirBnb.
# 3. Staten Island comes next, then Queens, and finally the Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No negative insights that lead to negative growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

#Analise Room type at Airbnb VS Average Prices
room_type_price=data1.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index()
room_type_price.rename(columns={'price':'Avg Price'},inplace=True)
room_type_price
# Out:
#    neighbourhood_group        room_type   Avg Price
# 0                Bronx  Entire home/apt  131.682390
# 1                Bronx     Private room   66.822018
# 2                Bronx      Shared room   61.200000
# 3             Brooklyn  Entire home/apt  187.742052
# 4             Brooklyn     Private room   80.756127
# 5             Brooklyn      Shared room   47.271242
# 6            Manhattan  Entire home/apt  268.215614
# 7            Manhattan     Private room  127.971560
# 8            Manhattan      Shared room   84.517857
# 9               Queens  Entire home/apt  155.343871
# 10              Queens     Private room   69.043697
# 11              Queens      Shared room   65.419753
# 12       Staten Island  Entire home/apt  176.776316
# 13       Staten Island     Private room   61.070175
# 14       Staten Island      Shared room   62.125000

# %%
d2=sns.barplot(data=room_type_price,x='room_type',y='Avg Price',hue='neighbourhood_group')
d2.set_ylabel('Average price')
d2.set_title('Avrage price chart')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As we know vertical bar charts are useful to compare different categorical or discrete variables.we have room type as categorical variable and price as continious and 3rd variable 'neighbourhood_group' which is again discreate variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We can clearly see that in Diffrent room types maximum avrage prices of AirBnb is in Manhattan (Green color bar).
# 2. We can see that 'Entire home/apt' has the higest average price followed by 'private room' and 'shared room'.
# 3. Brooklyn AirBnb has the 2nd highest avrage price in 'Entire home/apt' and 'private room' but not in 'shared room'.
# 4.There is huge gap of avrage price between 'Entire home/apt' and 'private room' in most of the neighbourhood_group. e

# %% [markdown]
# Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes the insights will dafinately help in creating positive business impact.
# As its clear from the chart which ''room type' in spacific 'neighbourhood_group' have what average price.They can work on spacific 'neighbourhood_group' and its avrage price to attract more clients.
#
# no there no negative insights in this visualization.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# ## Determine which neighborhood group has the most AirBnb count.

# %%
# Chart - 3 visualization code

Max_airbnb_in_neighbourhood=data1['neighbourhood_group'].value_counts().reset_index()
Max_airbnb_in_neighbourhood.rename(columns={'neighbourhood_group':'Total_count','index':'neighbourhood_group'},inplace=True)
Max_airbnb_in_neighbourhood
# Out:
#   neighbourhood_group  Total_count
# 0           Manhattan        13559
# 1            Brooklyn        12253
# 2              Queens         4298
# 3               Bronx          913
# 4       Staten Island          331

# %%
#Analising  neighbourhood_group have maximum number of Airbnb in Pie chart.

data1['neighbourhood_group'].value_counts().plot.pie(explode=[0.05,0.05,0.05,0.05,0.05],autopct='%1.0f%%',figsize=(10,5))
print(plt.title("% Distribution of AirBnb in neighbourhood group"))
plt.show()
# Out:
# Text(0.5, 1.0, '% Distribution of AirBnb in neighbourhood group')

# %%
#Analising neighbourhood_group have maximum number of Airbnb in bar chart
airbnb_in_neighbourhood=sns.barplot(data=Max_airbnb_in_neighbourhood,x='neighbourhood_group',y='Total_count')
airbnb_in_neighbourhood.set_ylabel('Numbers of Airbnb')
airbnb_in_neighbourhood.set_title('Number of AirBnb in every neighbourhood')
# Out:
# Text(0.5, 1.0, 'Number of AirBnb in every neighbourhood')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Pie charts make sense to show a parts-to-whole relationship for categorical.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The slices in the pie typically represent percentages of the total.Percentage of all the Airbnb is distrbuted in every neighbourhood_group.
#
# 2. We found that Manhattan have higest 43% cover up the pie chart.Manhattan has highest number of total AirBnb which is 13559.
#
# 3. After Manhattan ,Broklyn cover up 39% of total pie chart.With 2nd highest count of total AirBnb which is 12253.
#
# 4. Queens cover up 14% with 4298 AirBnb.
#
# 5. Bronx cover up 3% which is quite low as compared to Manhattan ,Brooklyn and Queens.
# 6. Lowest AirBnb are in Staten Island that cover only 1% of total 100%. wihich is total AirBnb =331.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes gained insights will help creating a positive impact on bussiness. As company can clerly show that how much percentage of distribution of AirBnb in each neighbourhood_group.
#
# Yes there are insights that lead to negative growth. As we can clearly see that Staten Island and Bronx have quite low total numbers of AirBnb's.Company shoud foud out the reason of such a low AirBnbs in these neighbourhood_group.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# ## Determine which neighborhood group has the most AirBnb count with respect to room_type.

# %%
# Chart - 4 visualization code
ab=data1.groupby(['neighbourhood_group'],as_index=False)['room_type'].value_counts()
d3=sns.barplot(data=ab,x='neighbourhood_group',y='count',hue='room_type')
d3.set_title('AirBnb count in respect to Neighbourhood_group and Room type',size=10)
# Out:
# Text(0.5, 1.0, 'AirBnb count in respect to Neighbourhood_group and Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It was interesting to look at the percentage of Airbnbs compared to the room type. The majority of listings were entire homes or apartments.
#
# 1. We found out that 'Entire home/apt' room type AirBnb are maximum in  Manhattan which is more than 8000 AirBnb's and minimum  in Staten Island.
# 2. We found that 'Private room' type AirBnb are maximum in Brooklyn and minimum in Staten Island.
# 3. We can clearly see that 'shared room' type are quote low in all neighbourhood group with is less than 700 AirBnb. and minuimum in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# ##### Are there any insights that lead to negative growth? Justify with specific reason.?
#
# Yes. The gained insights help creating a positive business impact. because the count of all room type with respect to neighbourhood group is clearly seen in this chart.

# %% [markdown]
# Yes. Huge gap in count of AirBnb in Manhattan,Brooklyn,Queen with respact to Bronx and staten Island.Which could lead to low stablishment and low choise of AirBnb in Staten Island and Bronx.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# ## Determine the density of Airbnb in New York with respct to 'neighbourhood_group.

# %%
# Chart - 5 visualization code
d4=sns.scatterplot(data=data1,x='longitude', y='latitude',hue='neighbourhood_group')
d4.set_title('AirBnb location wise distributin in NY')
# Out:
# Text(0.5, 1.0, 'AirBnb location wise distributin in NY')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have chosen Scatter plots' because it's primary uses are to observe and show relationships between two numeric variables.and two numric variables are Latitude and Longitude and 3rd categorical variable 'neighbourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We can see the exact location of All Airbnb listings in there neighbourhood_group.
# 2. We had multiple listings with the same location, New York City has a huge population. Their city has multiple apartments that are stack on top of each other, so a lot of our listings had the same coordinates. Looking at the density map, Airbnbs are around points of interest.
# 3.latitude and longtitude visulalizes us that Brooklyn and Manhattan are the most dense with hotels and apartments followed by queens island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the gained insights will help creating a positive business impact indirectly.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# ## Determine the density of Airbnb in New York with respct to 'availability_365'.

# %%
# Chart - 6 visualization code
d5=sns.scatterplot(data=data1,x='longitude', y='latitude',hue='availability_365')
d5.set_title('Longitude Vs Latitude Vs Availability')
# Out:
# Text(0.5, 1.0, 'Longitude Vs Latitude Vs Availability')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have chosen Scatter plots' because it's primary uses are to observe and show relationships between two numeric variables.and two numric variables are Latitude and Longitude and 3rd discret variable 'availability_365.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We cam up with insights that density of room availability above 160 days are more in Queens,Brooklyn and some parts of Bronx.
# Minimum Availability of room less than 160 are higher in some parts of Manhatten and  Brooklyn and Queen.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# Determine the density of Airbnb in New York with respct to 'minimum_nights'<30 days.

# %%
# Chart - 7 visualization code

minum_nights1=data1[data1['minimum_nights']<30][['latitude','longitude','minimum_nights']]
minum_nights1.plot.scatter(x='latitude', y='longitude',c='minimum_nights',cmap='viridis')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have pick scatter chart becuace we have a two continious numarical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have plot the location of all the AirBnb with manimum night less than 30.
# As we can see the green and yellow dots only few have minimum nights range between 20-29 days.And mojority or AirBnb fall in this catagory fall 10 minimum nights.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# ## Chart - 8 visualization code

# %%
data[['price']].describe()
# Out:
#               price
# count  48895.000000
# mean     152.720687
# std      240.154170
# min        0.000000
# 25%       69.000000
# 50%      106.000000
# 75%      175.000000
# max    10000.000000

# %%
def price_catagory(price):
  if price<=80:
    return 'cheep'
  elif price>=80 and price<=500:
    return 'affordable'
  else:
    return 'Expensive'

# %%
plt.figure(figsize=(10,5))
count_price = sns.countplot(x=data['price'].apply(price_catagory))
count_price.set_title('Count Plot')
count_price.set_xlabel('Catogories of rooms')
count_price.set_ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.We found out that there are more than 3000 number of AirBnb listing who have a price leass than 80 $ which fall under the affordable catagories
# 2.We found out that more than 15000 and less than 2000 AirBnb listings fall under cheep catagories with price range of 80-500 `$.`
# 3.We found that very less number of AirBnb listing which is less than 3000 who have fall in expansive room type catagorie.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Its quite suprising that most of the AirBnb fall under the afordable and cheep catagories which is quite imprassive that company had metained its AirBnb price evenly.
#
# No i dont thik that there is any negative insights that lead to negative growth in the above chart.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
d6=sns.countplot(x='room_type',data=data1)
d6.set_title('Number of each room types')
# Out:
# Text(0.5, 1.0, 'Number of each room types')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that Entire Home and Apartment have the most AirBnB listings, with over 16000 total. Next, Private Room has the second-highest number of AirBnb listings which is 14000. The final point is that Shared room has about 1000 AirBnb listing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Its clearly visible that the choice of client in NYC are more for Entire Home /Apartment ,then Private romm and shared room.This can help company to more focus on lisitings which have Entire home/apt room type.And from the above prices chat we already obsreve that most of the revenue is coming from the Entire home and Apartment and private room AirBnb listings.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
ax = sns.scatterplot(data=data1,x='availability_365',y='price')
plt.title("Scatterplot_availability_365 Vs Price")
# Out:
# Text(0.5, 1.0, 'Scatterplot_availability_365 Vs Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have chosen Scatter plots' because it's primary uses are to observe and show relationships between two numeric variables.Variables are price and availability_360.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that most of the AirBnb lisiting with availability from 1 to 365 days lies between 10-2000 $.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

v1=data1.groupby('neighbourhood')['price'].median().head(10).reset_index()
plt.figure(figsize=(15,5))
d7=sns.barplot(data=v1,x='neighbourhood',y='price')
d7.set_title('Neighbourhood Vs Price')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Vs Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have categorical Variable as 'neighbourhood' and continuous variable as 'price'. so bar chat is best fit for such type of variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We can observe that from top 15 neighbourhood 'Battery Park City' is highest price of AirBnb of `160$ `. After that Bay Terrace and Arverne.
# 2. Bath Beach has the lowest price of 60$ approx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the gained insights help creating a positive business impact.Chart show clearly whish 'neighbourhood' have what price and how much low or high from other neighbourhood in bar chart.
#
# yes there are is insights that lead to negative growth.Sudden price gap in few neighbourhood can creat confusion between clients.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#highest revenue collection by room type

highest_revenue=data1.groupby('room_type')['price'].sum().reset_index()
highest_revenue
# Out:
#          room_type    price
# 0  Entire home/apt  3713318
# 1     Private room  1311891
# 2      Shared room    57018

# %%
plt.ticklabel_format(style='plain')
d8=sns.barplot(data=highest_revenue,x='room_type',y='price')
d8.set_title('Room Type Vs Price sum')
# Out:
# Text(0.5, 1.0, 'Room Type Vs Price sum')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Room Type is a categorical variable and price is continous variable.Bar chart is best to represet such type of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Find that entire home/apartment listing have the maximum sum of price among all properties falling under this category."
# 2. And shared room has minium.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
d10=sns.boxplot(x='room_type', y='availability_365', data=data1)
d10.set_title('Room_type Vs Availability')
# Out:
# Text(0.5, 1.0, 'Room_type Vs Availability')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are useful for comparing the distribution of different groups. They allow you to see the similarities and differences in the central tendency and spread between various categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We found that Shared room has the higest 'availability_365'.That means Shared room category has maximum AirBnb listing which have very high  availability days.
# 2.Shared room median fall at 250 days.
# 3.Private room type and Entier home/Apartment have almoset equal availability_365.

# %% [markdown]
# Chart - 14

# %%
sns.displot(data=data1,x='availability_365')
plt.title('Distribution of availability_365')
# Out:
# Text(0.5, 1.0, 'Distribution of availability_365')

# %%
data1['availability_365'].describe()
# Out:
# count    31354.000000
# mean       175.834439
# std        126.195374
# min          1.000000
# 25%         55.000000
# 50%        168.000000
# 75%        305.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar-like representation of the frequency or count of data points within specified bins. The height of each bar corresponds to the number of data points falling into that bin.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We found out that room availability from 0-15 and 350-360 days have maximum occurrance.
# 2. From 200 to 250 days have minimum occurrance.
# 3.Minimum 1 day and maximum 365 days availability are there in AirBnb listed.

# %% [markdown]
# 3.Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is wide range of AirBnb which have very low days of availability which is a draw back for the business.These can lead to loosing intrest of clients on AirBnb.Any competitors can easy take advantage of this draw back.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %% [markdown]
# ## Analyzing the  number of visits in different types of rooms in each neighbourhood group

# %%
review_data = data1.groupby(['neighbourhood_group','room_type'])['number_of_reviews'].sum().unstack()
review_data
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                          11209         14922          396
# Brooklyn                      238756        181568         4739
# Manhattan                     200817        182682         8768
# Queens                         56551         84729         2603
# Staten Island                   5545          5307           13

# %%
review_data.plot(kind='bar',stacked=True,figsize=(10,5))
plt.title('Number of reviews')
plt.legend()
plt.show()

# %%
visit_data1 = data1[data1['neighbourhood_group']=='Bronx'].groupby(['neighbourhood'])['number_of_reviews'].sum().sort_values(ascending=False).head(1)
visit_data2 = data1[data1['neighbourhood_group']=='Brooklyn'].groupby(['neighbourhood'])['number_of_reviews'].sum().sort_values(ascending=False).head(1)
visit_data3 = data1[data1['neighbourhood_group']=='Manhattan'].groupby(['neighbourhood'])['number_of_reviews'].sum().sort_values(ascending=False).head(1)
visit_data4 = data1[data1['neighbourhood_group']=='Queens'].groupby(['neighbourhood'])['number_of_reviews'].sum().sort_values(ascending=False).head(1)
visit_data5 = data1[data1['neighbourhood_group']=='Staten Island'].groupby(['neighbourhood'])['number_of_reviews'].sum().sort_values(ascending=False).head(1)
pd.concat([visit_data1,visit_data2,visit_data3,visit_data4,visit_data5]).plot(kind='bar',color='red',figsize=(10,5))
plt.title('Maximum visited neighbourhood of neighbourhood group (Bronx, Brooklyn, Manhattan, Queens, Staten Island) respectively')
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# On the basis of chat we found that maximum number of visits in neighbourhood in each neighbourhood_group is in Bedford-Stuyvesant

# %% [markdown]
# #### Chart - 16 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

correlation_matrix = data1.corr()


# Set the figure size
fig, ax = plt.subplots(figsize=(7,5))

# Create a heatmap using seaborn
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation of Variable')
# Out:
# <ipython-input-62-8b4d526c294e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data1.corr()
# Text(0.5, 1.0, 'Correlation of Variable')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have chosen heat map because Multiple variable relation can easy been shown by the help of heat map.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.  Each cell in the matrix shows the correlation coefficient between two variables. The diagonal of the matrix shows the correlation of each variable with itself, which is always equal to 1.
# 2.Negative correlation with negative cofficient and positive correlation with positive cofficient.
# 3.We found that price have positive corrrelation with all the varaible except reviews per month and longtude.
# 4.Availability 365 has a positive relation with minimim nights.As its obvious as availability of room increase minimum nights increases.
# 5.prics has a postive correlation with calculated host listing count.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Sure, here are some suggestions to improve the format and grammar of the provided text:
#
# The data sheet provides us with complete information about Airbnb and its business model. Airbnb is one of the biggest companies operating an online marketplace for long and short-term home stays in NYC (USA). After gathering insights from all the data we have, we can suggest a few points:
#
# 1. The Bronx and Staten Island have few Airbnb properties, while the city of Manhattan, Brooklyn, and Queens have the most. The Staten Island Ferry, which travels across New York Harbor, connects Staten Island and Lower Manhattan, thus the business should try to increase the amount of Airbnb listings in these places. The island also features Staten Zoo, a place where numerous birds and animals may be found. In order to encourage more hosts to advertise their properties on Airbnb, the business should launch an advertising campaign to draw travelers to Staten Island.
#
# 2. The number Private rooms and entire homes/apartments is high, however there are few listings for shared rooms, as we can see. The company should concentrate on boosting the amount of shared room listings on Airbnb because they are the most cost-effective choice.
#
# 3. While the majority of Airbnb listings cost under $175, others reach as high as `$10,000`. In order to make these pricey Airbnb listings more appealing to potential guests, the firm should concentrate on pricing them more affordably.
#
# 4. There are certain Airbnb rentals that are available for just one day out of every 365. If a client likes the home and wants to remain for longer than the limited number of days available, that may not be possible. In order to satisfy visitor preferences, the organization should encourage hosts to provide longer booking durations.
#
# 5. Potential customers may not trust an Airbnb listing if there are no or few reviews. To increase customer trust, the business should look into the factors that led to the negative reviews and collaborate with hosts to make improvements.
#
#  Thankyou

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# We finished our project! In the dataset, we tried out several techniques. First, we looked at different variables and focused on the 'Price' variable. Then, we checked how 'Price' is related to other variables and used them together to gain more insights.
#
# We encountered some missing data and unusual values, so we took care of those by handling them appropriately. Next, we ran some basic statistical tests to make sure our assumptions were correct.
#
# Additionally, we had categorical variables (like types or categories) that we transformed into numbers (dummy variables) to work with them more easily.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
